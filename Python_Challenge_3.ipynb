# %%
#Create a tuple with fixed product categories like Electronics, Stationery, and Clothing.

categories = ("Electronics", "Stationery", "Clothing")
print(categories)

#Create a list of products that can be updated dynamically.

products = ["TV", "Laptop", "Notebook", "Shirt"]
print(products)

#Add a new product (user input)

new_product = input("Enter a new product to add: ")
products.append(new_product)
print("Product added successfully!")

print(products)



print("Updated Product List:", products)

#Ask the user to input the index of a product to remove it from the list.

remove_index = int(input("Enter the index of the product to remove (0-based index): "))

print(" Final Inventory Summary:")
print("Categories (Tuple - Immutable):", categories)
print("Products (List - Mutable):", products)
# Out:
# ('Electronics', 'Stationery', 'Clothing')
# ['TV', 'Laptop', 'Notebook', 'Shirt']
# Enter a new product to add: Grocery
# Product added successfully!
# ['TV', 'Laptop', 'Notebook', 'Shirt', 'Grocery']
# Updated Product List: ['TV', 'Laptop', 'Notebook', 'Shirt', 'Grocery']
# Enter the index of the product to remove (0-based index): 1
#  Final Inventory Summary:
# Categories (Tuple - Immutable): ('Electronics', 'Stationery', 'Clothing')
# Products (List - Mutable): ['TV', 'Laptop', 'Notebook', 'Shirt', 'Grocery']
