# %% [markdown]
# create lambda function which returns list of charaters in your name

# %%
my_name =lambda name: list(name)
print(my_name("bhuvana eswaran"))
# Out:
# ['b', 'h', 'u', 'v', 'a', 'n', 'a', ' ', 'e', 's', 'w', 'a', 'r', 'a', 'n']
